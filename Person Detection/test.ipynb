# %%
from ultralytics import YOLO

# %%
model = YOLO('yolov8n.pt') 

# Use the model
results = model('zidane.jpg')
results[0].save('output.jpg')
# Out:
# [W1115 14:56:21.018377347 NNPACK.cpp:61] Could not initialize NNPACK! Reason: Unsupported hardware.
# image 1/1 /home/picsartacademy/Desktop/AI Survaillance Tasks/Person Detection/zidane.jpg: 384x640 2 Human faces, 3 Mans, 2 Suits, 1656.3ms
# Speed: 127.2ms preprocess, 1656.3ms inference, 148.3ms postprocess per image at shape (1, 3, 384, 640)
# 'output.jpg'

# %%
from IPython.display import Image

Image(filename='output.jpg')
